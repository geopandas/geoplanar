# %% [markdown]
# # Geoplanar Example with Building Footprints
#
# This notebook provides an example of preprocessing building footprints for the centre of Berlin.
#
# *Note that you will need to have pyarrow installed if you want to read the parquet files.
#
# ```
# conda install -c conda-forge pyarrow
#
# or
#
# pip install pyarrow
# ```
#
# Notebook contents:
#
# 0. Import data and make valid, explode multipolygons, keep only polygons
#
# 1. Overlapping buildings
#
#     1a. Merge overlapping buildings
#
#     1b. Trim remaining overlapping buildings
#
# 2. Merge collapsed buildings
# 3. Snap buildings

# %% [markdown]
# ## 0. Import data and make valid, explode multipolygons, keep only polygons

# %%
import numpy as np
import geopandas as gpd
import geoplanar

# %%
buildings = gpd.read_parquet("../../../geoplanar/datasets/buildings_berlin.parquet")
buildings = buildings.to_crs(crs=31468)

# %%
buildings.plot()
# Out:
# <Axes: >

# %%
buildings.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcb94e83e82424fdc828b970cb1773a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcb94e83e82424fdc828b970cb1773a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fcb94e83e82424fdc828b970cb1773a0 = L.map(
#                 &quot;map_fcb94e83e82424fdc828b970cb1773a0&quot;,
#                 {
#                     center: [52.51493835449219, 13.389838218688954],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_fcb94e83e82424fdc828b970cb1773a0);
#
#
#
#
#
#             var tile_layer_af0b2047ebf5ded5be3bfc8aee506a48 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af0b2047ebf5ded5be3bfc8aee506a48.addTo(map_fcb94e83e82424fdc828b970cb1773a0);
#
#
#             map_fcb94e83e82424fdc828b970cb1773a0.fitBounds(
#                 [[52.49849319458008, 13.35630989074706], [52.53138351440429, 13.423366546630847]],
#                 {}
#             );
#
#
#         function geo_json_15e3492feff1df85c1206ba6677d3dfe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_15e3492feff1df85c1206ba6677d3dfe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_15e3492feff1df85c1206ba6677d3dfe_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_15e3492feff1df85c1206ba6677d3dfe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_15e3492feff1df85c1206ba6677d3dfe_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_15e3492feff1df85c1206ba6677d3dfe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_15e3492feff1df85c1206ba6677d3dfe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_15e3492feff1df85c1206ba6677d3dfe = L.geoJson(null, {
#                 onEachFeature: geo_json_15e3492feff1df85c1206ba6677d3dfe_onEachFeature,
#
#                 style: geo_json_15e3492feff1df85c1206ba6677d3dfe_styler,
#                 pointToLayer: geo_json_15e3492feff1df85c1206ba6677d3dfe_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_15e3492feff1df85c1206ba6677d3dfe_add (data) {
#             geo_json_15e3492feff1df85c1206ba6677d3dfe
#                 .addData(data);
#         }
#             geo_json_15e3492feff1df85c1206ba6677d3dfe_add({&quot;bbox&quot;: [13.35630989074706, 52.49849319458008, 13.423366546630847, 52.53138351440429], &quot;features&quot;: [{&quot;bbox&quot;: [13.374549865722653, 52.50954437255858, 13.375488281249984, 52.509788513183594], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.374549865722653, 52.50972366333007], [13.375261306762685, 52.509780883789055], [13.375389099121087, 52.509788513183594], [13.375396728515618, 52.509761810302734], [13.37540340423583, 52.50972747802734], [13.375488281249984, 52.509735107421875], [13.375474929809556, 52.50971221923828], [13.375452041625971, 52.50968933105469], [13.375425338745114, 52.50966644287109], [13.375369071960433, 52.50962829589844], [13.375315666198722, 52

# %%
buildings.type.value_counts()
# Out:
# Polygon         8714
# MultiPolygon       2
# Name: count, dtype: int64

# %%
# make valid
buildings["geometry"] = buildings.make_valid()

# %%
buildings.type.value_counts()
# Out:
# Polygon               8710
# MultiPolygon             4
# GeometryCollection       2
# Name: count, dtype: int64

# %%
# explode GeometryCollection and MultiPolygon
buildings = buildings.explode(ignore_index=True)

# %%
buildings.type.value_counts()
# Out:
# Polygon       8721
# LineString       2
# Name: count, dtype: int64

# %%
# remove non-Polygon geometries
buildings = buildings[buildings.type == "Polygon"]

# %%
buildings.type.value_counts()
# Out:
# Polygon    8721
# Name: count, dtype: int64

# %% [markdown]
# ## 1. Overlapping buildings

# %% [markdown]
# ### 1a. Merge overlapping buildings

# %%
buildings=buildings.reset_index(drop=True)
buildings.shape
# Out:
# (8721, 1)

# %%
# set precision so that polygons don't have rounding errors and are effectively snapped to the same precision grid
buildings["geometry"] = buildings.set_precision(0.00001)
buildings.shape
# Out:
# (8721, 1)

# %%
buildings.type.value_counts()
# Out:
# Polygon    8721
# Name: count, dtype: int64

# %%
## merge buildings that overlap either 1) at least .10 percent or 2) 500sqm
buildings = geoplanar.merge_overlaps(buildings, merge_limit=500, overlap_limit=0.1)
buildings.shape
# Out:
# (8620, 1)

# %%
#the output may result in MultiPolygons. This is typically a result of a complex relationship between geometries and is expected. 
# These multipolygons are usually comprised of just one polygon so can be exploded
buildings.type.value_counts()
# Out:
# Polygon    8620
# Name: count, dtype: int64

# %%
buildings.type.value_counts()
# Out:
# Polygon    8620
# Name: count, dtype: int64

# %% [markdown]
# ### 1b. Trim overlapping buildings

# %%
from collections import defaultdict

import geopandas
import libpysal
import numpy as np
from packaging.version import Version
from esda.shape import isoperimetric_quotient

__all__ = [
    "overlaps",
    "trim_overlaps",
    "is_overlapping",
    "merge_overlaps",
    "merge_touching",
]

GPD_GE_014 = Version(geopandas.__version__) >= Version("0.14.0")



def trim_overlaps(gdf, strategy='largest', inplace=False):


    """Trim overlapping polygons

    Note
    ----
    Under certain circumstances, the output may result in MultiPolygons. This is
    typically a result of a complex relationship between geometries and is expected.
    Just note, that it may require further treatment if simple Polygons are needed.

    Parameters
    ----------

    gdf:  geodataframe with polygon geometries

    strategy : {'smallest', 'largest', 'compact', None}, default 'largest'
        Strategy to determine which polygon to trim.
          - 'smallest': Trim the smallest polygon.
          - 'largest' : Trim the largest polygon.
          - 'compact' : Trim the polygon yielding the most compact modified polygon.
                            (isoperimetric quotient).
          - None      : Trim either polygon non-deterministically but performantly.
    
    Returns
    -------

    gdf: geodataframe with corrected geometries

    """
    if GPD_GE_014:
        intersections = gdf.sindex.query(gdf.geometry, predicate="overlaps").T
    else:
        intersections = gdf.sindex.query_bulk(gdf.geometry, predicate="overlaps").T

    if not inplace:
        gdf = gdf.copy()

    geom_col_idx = gdf.columns.get_loc(gdf.geometry.name)

    if strategy is None:  # don't care which polygon to trim
        for i, j in intersections:
            if i != j:
                left = gdf.geometry.iloc[i]
                right = gdf.geometry.iloc[j]
                gdf.iloc[j, geom_col_idx] = right.difference(left)
    elif strategy=='largest':
        for i, j in intersections:
            if i != j:
                left = gdf.geometry.iloc[i]
                right = gdf.geometry.iloc[j]
                if left.area > right.area:  # trim left
                    gdf.iloc[i, geom_col_idx] = left.difference(right)
                else:
                    gdf.iloc[j, geom_col_idx] = right.difference(left)
    elif strategy=='smallest':
        for i, j in intersections:
            if i != j:
                left = gdf.geometry.iloc[i]
                right = gdf.geometry.iloc[j]
                if left.area < right.area:  # trim left
                    gdf.iloc[i, geom_col_idx] = left.difference(right)
                else:
                    gdf.iloc[j, geom_col_idx] = right.difference(left)
    elif strategy=='compact':
         for i, j in intersections:
             if i != j:
                 left = gdf.geometry.iloc[i]
                 right = gdf.geometry.iloc[j]
                 left_c = left.difference(right)
                 right_c = right.difference(left)
                 iq_left = isoperimetric_quotient(left_c)
                 iq_right = isoperimetric_quotient(right_c)
                 if iq_left > iq_right:  # trimming left is more compact than right
                     gdf.iloc[i, geom_col_idx] = left_c
                 else:
                     gdf.iloc[j, geom_col_idx] = right_c
    return gdf

# %%
## trim remaining overlaps
buildings = trim_overlaps(buildings, strategy="largest")
buildings.shape
# Out:
# (8620, 1)

# %%
buildings.type.value_counts()
# Out:
# Polygon    8620
# Name: count, dtype: int64

# %%
# check for remaining overlaps
overlaps = geoplanar.overlaps(buildings)

# %%
overlaps
# Out:
# array([[  58,   67,  575, 4208, 4729, 4748, 4908, 5605, 5633, 5794, 6428,
#         6432, 6494, 7291, 8051, 8520, 8520, 8564],
#        [7291, 5605, 6494, 5794, 4748, 4729, 5633,   67, 4908, 4208, 6432,
#         6428,  575,   58, 8520, 8564, 8051, 8520]])

# %%
# remaining overlaps result from floating point errors
buildings.iloc[overlaps[0]].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93469024de12fac611f6b2ce33a32008 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93469024de12fac611f6b2ce33a32008&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93469024de12fac611f6b2ce33a32008 = L.map(
#                 &quot;map_93469024de12fac611f6b2ce33a32008&quot;,
#                 {
#                     center: [52.51682472229635, 13.3925380706852],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_93469024de12fac611f6b2ce33a32008);
#
#
#
#
#
#             var tile_layer_9d74e9518c7ba9bb8546a6443c032ae4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d74e9518c7ba9bb8546a6443c032ae4.addTo(map_93469024de12fac611f6b2ce33a32008);
#
#
#             map_93469024de12fac611f6b2ce33a32008.fitBounds(
#                 [[52.50342559813792, 13.368006706185401], [52.530223846454774, 13.417069435184999]],
#                 {}
#             );
#
#
#         function geo_json_ef33d052d40e8bc99464395204eff3e2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ef33d052d40e8bc99464395204eff3e2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ef33d052d40e8bc99464395204eff3e2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ef33d052d40e8bc99464395204eff3e2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ef33d052d40e8bc99464395204eff3e2_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ef33d052d40e8bc99464395204eff3e2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ef33d052d40e8bc99464395204eff3e2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ef33d052d40e8bc99464395204eff3e2 = L.geoJson(null, {
#                 onEachFeature: geo_json_ef33d052d40e8bc99464395204eff3e2_onEachFeature,
#
#                 style: geo_json_ef33d052d40e8bc99464395204eff3e2_styler,
#                 pointToLayer: geo_json_ef33d052d40e8bc99464395204eff3e2_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_ef33d052d40e8bc99464395204eff3e2_add (data) {
#             geo_json_ef33d052d40e8bc99464395204eff3e2
#                 .addData(data);
#         }
#             geo_json_ef33d052d40e8bc99464395204eff3e2_add({&quot;bbox&quot;: [13.368006706185401, 52.50342559813792, 13.417069435184999, 52.530223846454774], &quot;features&quot;: [{&quot;bbox&quot;: [13.40215969081937, 52.51395416255947, 13.402877807652382, 52.51436614992799], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.402394294709538, 52.51395416255947], [13.40215969081937, 52.51411819457644], [13.40245628359873, 52.51427459712652], [13.402461051936509, 52.51427078249491], [13.402470588736835, 52.51427459718414], [13.402654647790719, 52.51436614992799], [13.402877807652382, 52.5142135619968], [13.402705192639564, 52.51412200931704], [13.40263557439961, 52.51416778563093], [13.402576446503232, 52.51420974735696], [13.402556419364933, 52.514198

# %% [markdown]
# ## 2. Merge Collapsed Buildings

# %% [markdown]
# Checks for tiny polygons which are too small to represent individual buildings. Buffer size can be changed from 0.4 to the appropriate distance.

# %%
buildings = buildings.reset_index(drop=True)

# %%
buildings
# Out:
#                                                geometry
# 0     POLYGON ((4593474.968 5820516.514, 4593483.628...
# 1     POLYGON ((4593637.723 5821622.766, 4593637.682...
# 2     POLYGON ((4593340.989 5821617.532, 4593335.228...
# 3     POLYGON ((4593637.228 5821648.658, 4593637.593...
# 4     POLYGON ((4593048.473 5822123.631, 4593039.152...
# ...                                                 ...
# 8615  POLYGON ((4595744.168 5819514.447, 4595745.47 ...
# 8616  POLYGON ((4593324.001 5822407.84, 4593311.809 ...
# 8617  POLYGON ((4595410.803 5821222.138, 4595446.032...
# 8618  POLYGON ((4593894.427 5821361.441, 4593937.58 ...
# 8619  POLYGON ((4596233.141 5822815.254, 4596228.114...
#
# [8620 rows x 1 columns]

# %%
shrink=buildings.buffer(-0.4, resolution=2)
emptycheck = shrink.is_empty

# %%
buildings.loc[shrink.is_empty]
# Out:
#                                                geometry
# 487   POLYGON ((4592587.167 5820479.718, 4592587.491...
# 2259  POLYGON ((4593697.054 5820923.71, 4593697.046 ...
# 3010  POLYGON ((4593646.046 5820966.471, 4593648.312...
# 3079  POLYGON ((4593642.744 5820966.408, 4593644.945...
# 3165  POLYGON ((4593649.42 5820966.111, 4593649.412 ...
# 3592  POLYGON ((4593654.972 5820967.066, 4593654.988...
# 7786  POLYGON ((4595508.06 5820890.281, 4595526.757 ...

# %%
buildings.loc[shrink.is_empty].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a5b44ebc5497c654bd108e203d0a68e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a5b44ebc5497c654bd108e203d0a68e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a5b44ebc5497c654bd108e203d0a68e = L.map(
#                 &quot;map_9a5b44ebc5497c654bd108e203d0a68e&quot;,
#                 {
#                     center: [52.51169898637944, 13.38391256335681],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9a5b44ebc5497c654bd108e203d0a68e);
#
#
#
#
#
#             var tile_layer_00d290a86989eb2d3a301be398ac8f63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00d290a86989eb2d3a301be398ac8f63.addTo(map_9a5b44ebc5497c654bd108e203d0a68e);
#
#
#             map_9a5b44ebc5497c654bd108e203d0a68e.fitBounds(
#                 [[52.50960021274299, 13.36217880252698], [52.5137977600159, 13.405646324186641]],
#                 {}
#             );
#
#
#         function geo_json_b109cb94986032216ed52bbfe4672851_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b109cb94986032216ed52bbfe4672851_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b109cb94986032216ed52bbfe4672851_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b109cb94986032216ed52bbfe4672851_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b109cb94986032216ed52bbfe4672851_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b109cb94986032216ed52bbfe4672851.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b109cb94986032216ed52bbfe4672851_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b109cb94986032216ed52bbfe4672851 = L.geoJson(null, {
#                 onEachFeature: geo_json_b109cb94986032216ed52bbfe4672851_onEachFeature,
#
#                 style: geo_json_b109cb94986032216ed52bbfe4672851_styler,
#                 pointToLayer: geo_json_b109cb94986032216ed52bbfe4672851_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b109cb94986032216ed52bbfe4672851_add (data) {
#             geo_json_b109cb94986032216ed52bbfe4672851
#                 .addData(data);
#         }
#             geo_json_b109cb94986032216ed52bbfe4672851_add({&quot;bbox&quot;: [13.36217880252698, 52.50960021274299, 13.405646324186641, 52.5137977600159], &quot;features&quot;: [{&quot;bbox&quot;: [13.36217880252698, 52.50960021274299, 13.362184951239351, 52.50960159299155], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.36217880252698, 52.50960159299155], [13.362183570917772, 52.50960159298492], [13.362184951239351, 52.50960021274299], [13.36217880252698, 52.50960159299155]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;487&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [13.378645896959343, 52.51340103151556, 13.378680229234375, 52.51340484621941], &quot;geometry&quot;: {&quot;coordina

# %%
# merge touching collapsing buildings
buildings = geoplanar.merge_touching(buildings, shrink.is_empty, largest=True)
buildings.shape
# Out:
# (8613, 1)

# %%
# check if merge_touching has worked
shrink=buildings.buffer(-0.4, resolution=2)
emptycheck = shrink.is_empty
buildings[emptycheck]
# Out:
# Empty GeoDataFrame
# Columns: [geometry]
# Index: []

# %% [markdown]
# ## 3. Snap Buildings

# %%
# snap nearby buildings
buildings["geometry"] = geoplanar.snap(buildings, threshold=0.5)
buildings.shape
# Out:
# (8613, 1)

# %%
buildings.type.value_counts()
# Out:
# Polygon    8613
# Name: count, dtype: int64

# %%
buildings
# Out:
#                                                geometry
# 0     POLYGON ((4593474.968 5820516.514, 4593483.628...
# 1     POLYGON ((4593637.723 5821622.766, 4593637.682...
# 2     POLYGON ((4593340.989 5821617.532, 4593335.228...
# 3     POLYGON ((4593637.228 5821648.658, 4593637.593...
# 4     POLYGON ((4593048.473 5822123.631, 4593039.152...
# ...                                                 ...
# 8615  POLYGON ((4595744.168 5819514.447, 4595745.47 ...
# 8616  POLYGON ((4593324.001 5822407.84, 4593311.809 ...
# 8617  POLYGON ((4595410.803 5821222.138, 4595446.032...
# 8618  POLYGON ((4593894.427 5821361.441, 4593937.58 ...
# 8619  POLYGON ((4596233.141 5822815.254, 4596228.114...
#
# [8613 rows x 1 columns]

# %%
buildings.is_valid.value_counts()
# Out:
# True    8613
# Name: count, dtype: int64

# %%
# The following should not be part of the example but I think snapping is not working as expected
# because before and after snapping, the snapping algorithm still identifies the same pairs to snap

# %%
# before snapping

# %%
nearby_a, nearby_b = buildings.sindex.query(
        buildings.geometry, predicate="dwithin", distance=0.5
    )

# %%
len(nearby_a)
# Out:
# 20853

# %%
import pandas as pd

# %%
nearby_a, nearby_b = buildings.sindex.query(
    buildings.geometry, predicate="dwithin", distance=0.5
)
overlap_a, overlap_b = buildings.boundary.sindex.query(
    buildings.boundary, predicate="overlaps"
)

self_mask = nearby_a != nearby_b
nearby_a = nearby_a[self_mask]
nearby_b = nearby_b[self_mask]

self_mask = overlap_a != overlap_b
overlap_a = overlap_a[self_mask]
overlap_b = overlap_b[self_mask]

nearby = pd.MultiIndex.from_arrays([nearby_a, nearby_b], names=("source", "target"))
overlap = pd.MultiIndex.from_arrays(
    [overlap_a, overlap_b], names=("source", "target")
)
nearby_not_overlap = nearby.difference(overlap)

# %%
nearby_not_overlap
# Out:
# MultiIndex([(  39, 1446),
#             (  39, 7171),
#             (  40, 7273),
#             (  54,   57),
#             (  56,   57),
#             (  57,   54),
#             (  57,   56),
#             (  71, 7937),
#             (  93,  143),
#             (  95,  160),
#             ...
#             (8454, 8452),
#             (8454, 8453),
#             (8477, 5017),
#             (8499, 5109),
#             (8501, 1292),
#             (8504, 6806),
#             (8549, 5609),
#             (8581, 7992),
#             (8599, 5810),
#             (8612, 6432)],
#            names=['source', 'target'], length=860)

# %%
# after snapping

# %%
geometry = buildings

# %%
threshold=0.5

# %%
if not nearby_not_overlap.empty:
    duplicated = pd.DataFrame(
        np.sort(np.array(nearby_not_overlap.to_list()), axis=1)
    ).duplicated()
    pairs_to_snap = nearby_not_overlap[~duplicated]

# %%
pairs_to_snap
# Out:
# MultiIndex([(  39, 1446),
#             (  39, 7171),
#             (  40, 7273),
#             (  54,   57),
#             (  56,   57),
#             (  71, 7937),
#             (  93,  143),
#             (  95,  160),
#             (  96, 7312),
#             ( 131, 7858),
#             ...
#             (7799, 7800),
#             (7977, 7979),
#             (7992, 8581),
#             (8128, 8256),
#             (8166, 8431),
#             (8202, 8303),
#             (8225, 8231),
#             (8452, 8453),
#             (8452, 8454),
#             (8453, 8454)],
#            names=['source', 'target'], length=430)
